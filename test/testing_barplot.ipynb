# %%
import sys
sys.path.append('../yyplot')

# %%
from bar import bar
from utility import barheight_helper #to do!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
# %matplotlib inline

# %%
a = np.random.randint(20,200,10)
b = np.random.rand(10)

# %%
df = pd.DataFrame({'freq':a, 'ratio':b})
df = df.sort(columns='freq')

# %%
bar('freq', df, title='Testing Bar plot', xlabel='Frequency')
